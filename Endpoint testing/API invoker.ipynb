# %%
# For QPOC Weighted Ensemble L3 Full
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "QPOC4-5db0a277d56e455e85a0a41274125d81"

# Prepare input data (assuming you have a CSV file)
input_data = "input_csv.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print('-----------------------------------')
    #print(response)
    print(response["Body"].read())
    print('-----------------------------------')
    print(f"Predicted label: \n{predicted_label}")
except Exception as e:
    print(f"Error making SageMaker API request: {e}")

# %%
# For Questionnaire POC XGBoost
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "QPOC6-a332c00ba1674779b1d59eadcf6c338e"

# Prepare input data (assuming you have a CSV file)
input_data = "input_csv.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# 1837,0.7173275947570801
# 1883,0.7058590054512024
# 1844,0.7165814638137817
# 1852,0.7158783674240112
# 1835,0.7151251435279846
# 1895,0.7174222469329834
# 1887,0.7148652076721191
# 1863,0.7161155343055725
# 3155,0.6682682037353516
# 1859,0.7169650793075562
# 1260,0.7093039751052856
# 1859,0.7169522047042847
# 1841,0.7169495224952698
# 1864,0.7163501977920532
# 1844,0.7165270447731018
# 1895,0.7151585221290588
# 1841,0.7171748280525208
# 1837,0.7172914743423462

# %%
# For Questionnaire POC Weighted Ensemble L2
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "QPOC10-WeightedEnsemble-L2-FULL-t1664145726992QPOC10"

# Prepare input data (assuming you have a CSV file)
input_data = "input_csv_QPOC10.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# 529/Coverdell Year End Statement,0.7348153591156006
# 1099-G Unemployment Compensation,0.7222229838371277
# Rental Income & Expenses (Per Property),0.7292752861976624
# Form 8332,0.7230595946311951
# Not Required,0.9910895824432373
# Loan Closing Statement,0.7353683114051819
# Not Required,0.9908605813980103
# Not Required,0.9907265901565552
# December Statement from CollegeInvest or other 529 plan provider,0.5794210433959961
# Not Required,0.9907870292663574
# Not Required,0.9909591674804688
# Not Required,0.9908252358436584
# Not Required,0.9911154508590698
# PPP Loan Details,0.7095387578010559
# Not Required,0.9908976554870605
# Loan Closing Statement,0.6979900598526001
# IRS/State Notices,0.9860327839851379
# Not Required,0.9909591674804688
# IRS/State Notices,0.9860327839851379
# 529/Coverdell Year End Statement,0.7351120710372925
# Not Required,0.9898450374603271
# Not Required,0.9905422329902649
# Not Required,0.990554690361023
# ...

# %%
# For Questionnaire POC Weighted Ensemble L2 (11 -> Only question answer based)
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "QPOC11-b769c8022f6747b9b60a7194661eb135"

# Prepare input data (assuming you have a CSV file)
input_data = "Input_Data_for_prediction_Qpoc11.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# Not Required,0.9999133348464966
# Not Required,0.999946117401123
# Taxpayer's Driver License,0.8611669540405273
# Loan Closing Statement,0.9930378198623657
# Tax Payments,0.840827465057373
# Crypto,0.846725344657898
# Not Required,0.9999415874481201
# Loan Closing Statement,0.9930378198623657
# Other Tax Payments,0.8499519228935242
# 0,0.8514116406440735
# 1099-G Unemployment Compensation,0.7077956795692444
# Not Required,0.9997607469558716
# Not Required,0.9996886253356934
# Other Tax Payments,0.7807818651199341

# %%
# For Questionnaire POC XGBoost(HPO) with TCCode prediction
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "QuestionnairePOCWithHPO-5d636d94f0be4031ac20cc7c05c05107"

# Prepare input data (assuming you have a CSV file)
input_data = "FinalDataSet_input.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# NOT REQUIERED,0.9887273907661438
# TC.MOV,0.40725383162498474
# NOT REQUIERED,0.9941149950027466
# TC.IRA,0.8747517466545105
# NOT REQUIERED,0.9103202819824219
# NOT REQUIERED,0.9939205050468445
# TC.IRA,0.8474656343460083
# TC.MOV,0.4445837140083313
# NOT REQUIERED,0.9953621625900269
# NOT REQUIERED,0.9934532046318054
# TC.WAG,0.7539628744125366
# NOT REQUIERED,0.8705779910087585
# NOT REQUIERED,0.8571990728378296
# TC.WAG,0.7355174422264099
# NOT REQUIERED,0.9823223352432251
# TC.WAG,0.8176267743110657
# TC.WAG,0.5792694091796875
# TC.WAG,0.8580500483512878
# NOT REQUIERED,0.8662986755371094
# TC.WAG,0.5362308621406555
# NOT REQUIERED,0.9407016038894653
# NOT REQUIERED,0.9932901263237
# NOT REQUIERED,0.9930127859115601
# TC.IRS,0.8674375414848328
# NOT REQUIERED,0.9844030141830444
# TC.IRS,0.6689444184303284
# TC.IRS,0.9040477871894836
# TC.IRS,0.7165711522102356
# NOT REQUIERED,0.9882436990737915

# %%
#WeightedEnsemble-L3-FULL-QuestionnairePOC-EP
# For Questionnaire POC WeightedEnsemble-L3-FULL with TCCode prediction
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "WeightedEnsemble-L3-FULL-QuestionnairePOC-EP"

# Prepare input data (assuming you have a CSV file)
input_data = "FinalDataSet_input.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# NOT REQUIERED,0.9806557893753052
# TC.MOV,0.871293306350708
# NOT REQUIERED,0.9829635620117188
# TC.IRA,0.971778929233551
# NOT REQUIERED,0.9829850196838379
# NOT REQUIERED,0.9828994274139404
# TC.IRA,0.9673830270767212
# TC.MOV,0.7516468167304993
# NOT REQUIERED,0.9829425811767578
# NOT REQUIERED,0.983036458492279
# TC.WAG,0.5123835206031799
# NOT REQUIERED,0.9828610420227051
# NOT REQUIERED,0.9830561876296997
# TC.WAG,0.8778022527694702
# NOT REQUIERED,0.9830513000488281
# TC.WAG,0.4373244047164917
# TC.OTH,0.39921486377716064
# TC.WAG,0.9161728024482727
# NOT REQUIERED,0.9827379584312439
# TC.WAG,0.7530816197395325
# NOT REQUIERED,0.982985258102417
# NOT REQUIERED,0.9829844832420349
# NOT REQUIERED,0.9830358028411865
# TC.IRS,0.8179267644882202
# NOT REQUIERED,0.982647180557251
# TC.IRS,0.6018254160881042
# TC.IRS,0.5802184343338013
# TC.IRS,0.8644368648529053
# NOT REQUIERED,0.98298579454422

# %%
#WeightedEnsemble-L3-QuestionnairePOCWithEnsembling-EP
# For Questionnaire POC WeightedEnsemble-L3 with TCCode prediction
import boto3
import pandas as pd

# Initialize SageMaker client
sagemaker_client = boto3.client("sagemaker-runtime", region_name="us-east-1")

# Define the endpoint name
endpoint_name = "WeightedEnsemble-L3-QuestionnairePOCWithEnsembling-EP"

# Prepare input data (assuming you have a CSV file)
input_data = "FinalDataSet_input.csv"

# Read input data from CSV
input_df = pd.read_csv(input_data)

# Convert input data to CSV string
input_csv = input_df.to_csv(index=False, header=False)

# Set headers for the request
headers = {
    "Content-Type": "text/csv",
    "Accept": "text/csv"
}

# Make the API request to SageMaker endpoint
try:
    response = sagemaker_client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType="text/csv",
        Body=input_csv.encode("utf-8")
    )
    predicted_label = response["Body"].read().decode("utf-8").strip()  # Extract the predicted label
    print(f"Predicted label: \n{predicted_label}") 
except Exception as e:
    print(f"Error making SageMaker API request: {e}")
# Out:
# Predicted label:
# NOT REQUIERED,0.9999077320098877
# TC.MOV,0.9866838455200195
# NOT REQUIERED,0.9989169239997864
# TC.IRA,0.9822173118591309
# NOT REQUIERED,0.9992803335189819
# NOT REQUIERED,0.9988898038864136
# TC.IRA,0.9410892724990845
# TC.MOV,0.9683415293693542
# NOT REQUIERED,0.9995204210281372
# NOT REQUIERED,0.9997902512550354
# TC.WAG,0.5694136023521423
# NOT REQUIERED,0.9995602369308472
# NOT REQUIERED,0.9994816184043884
# TC.WAG,0.9069710969924927
# NOT REQUIERED,0.9994978904724121
# TC.WAG,0.8909252882003784
# TC.WAG,0.7680699229240417
# TC.WAG,0.8800502419471741
# NOT REQUIERED,0.9988256692886353
# TC.WAG,0.93492192029953
# NOT REQUIERED,0.9984866380691528
# NOT REQUIERED,0.9986125230789185
# NOT REQUIERED,0.9993813633918762
# TC.CPA,0.6765302419662476
# NOT REQUIERED,0.9991745948791504
# TC.CPA,0.5534548759460449
# TC.CPA,0.6771566867828369
# TC.IRS,0.5055484175682068
# NOT REQUIERED,0.9984127283096313
